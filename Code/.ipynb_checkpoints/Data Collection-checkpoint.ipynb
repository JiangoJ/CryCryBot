# %%
import websocket, json, pprint, talib, numpy
from binance.client import Client
from binance.enums import *
import config

# %%
SOCKET = "wss://stream.binance.com:9443/ws/ethusdt@kline_1m"

RSI_PERIOD = 14
RSI_OVERBOUGHT = 70
RSI_OVERSOLD = 30
TRADE_SYMBOL = 'ETHUSD'
TRADE_QUANTITY = 0.05

closes = []
in_position = False

client = Client(config.KEY, config.SECRET, tld='us')

def order(side, quantity, symbol,order_type=ORDER_TYPE_MARKET):
    try:
        print("sending order")
        order = client.create_order(symbol=symbol, side=side, type=order_type, quantity=quantity)
        print(order)
    except Exception as e:
        print("an exception occured - {}".format(e))
        return False

    return True

    
def on_open(ws):
    print('opened connection')

def on_close(ws):
    print('closed connection')

def on_message(ws, message):
    global closes, in_position
    
    print('received message')
    json_message = json.loads(message)
    pprint.pprint(json_message)

    candle = json_message['k']

    is_candle_closed = candle['x']
    close = candle['c']

    if is_candle_closed:
        print("candle closed at {}".format(close))
        closes.append(float(close))
        print("closes")
        print(closes)

        if len(closes) > RSI_PERIOD:
            np_closes = numpy.array(closes)
            rsi = talib.RSI(np_closes, RSI_PERIOD)
            print("all rsis calculated so far")
            print(rsi)
            last_rsi = rsi[-1]
            print("the current rsi is {}".format(last_rsi))

            if last_rsi > RSI_OVERBOUGHT:
                if in_position:
                    print("Overbought! Sell! Sell! Sell!")
                    # put binance sell logic here
                    order_succeeded = order(SIDE_SELL, TRADE_QUANTITY, TRADE_SYMBOL)
                    if order_succeeded:
                        in_position = False
                else:
                    print("It is overbought, but we don't own any. Nothing to do.")
            
            if last_rsi < RSI_OVERSOLD:
                if in_position:
                    print("It is oversold, but you already own it, nothing to do.")
                else:
                    print("Oversold! Buy! Buy! Buy!")
                    # put binance buy order logic here
                    order_succeeded = order(SIDE_BUY, TRADE_QUANTITY, TRADE_SYMBOL)
                    if order_succeeded:
                        in_position = True

                
ws = websocket.WebSocketApp(SOCKET, on_open=on_open, on_close=on_close, on_message=on_message)
ws.run_forever()
# Out:
# opened connection
# received message
# {'E': 1650834324952,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036270,
#        'Q': '63812.83012800',
#        'T': 1650834359999,
#        'V': '21.70110000',
#        'c': '2940.96000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 58,
#        'o': '2940.38000000',
#        'q': '77196.98079300',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '26.25200000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834327232,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036271,
#        'Q': '63812.83012800',
#        'T': 1650834359999,
#        'V': '21.70110000',
#        'c': '2940.95000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 59,
#        'o': '2940.38000000',
#        'q': '77214.62649300',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '26.25800000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834329550,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036275,
#        'Q': '63812.83012800',
#        'T': 1650834359999,
#        'V': '21.70110000',
#        'c': '2940.95000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 63,
#        'o': '2940.38000000',
#        'q': '78621.57697300',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '26.73640000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834332170,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036285,
#        'Q': '63945.74931600',
#        'T': 1650834359999,
#        'V': '21.74630000',
#        'c': '2940.69000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 73,
#        'o': '2940.38000000',
#        'q': '93348.09188300',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '31.74420000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834335903,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036286,
#        'Q': '63945.74931600',
#        'T': 1650834359999,
#        'V': '21.74630000',
#        'c': '2940.68000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 74,
#        'o': '2940.38000000',
#        'q': '93466.89535500',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '31.78460000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834338208,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036298,
#        'Q': '64773.82827600',
#        'T': 1650834359999,
#        'V': '22.02790000',
#        'c': '2940.56000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 86,
#        'o': '2940.38000000',
#        'q': '95108.93787100',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '32.34300000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834341221,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036299,
#        'Q': '65259.02232600',
#        'T': 1650834359999,
#        'V': '22.19290000',
#        'c': '2940.57000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 87,
#        'o': '2940.38000000',
#        'q': '95594.13192100',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '32.50800000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834343336,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036301,
#        'Q': '65309.89418700',
#        'T': 1650834359999,
#        'V': '22.21020000',
#        'c': '2940.57000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 89,
#        'o': '2940.38000000',
#        'q': '95680.29050200',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '32.53730000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834346242,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036304,
#        'Q': '67829.37456300',
#        'T': 1650834359999,
#        'V': '23.06700000',
#        'c': '2940.57000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 92,
#        'o': '2940.38000000',
#        'q': '98314.74677400',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '33.43320000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834348370,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036307,
#        'Q': '68070.20724600',
#        'T': 1650834359999,
#        'V': '23.14890000',
#        'c': '2940.57000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 95,
#        'o': '2940.38000000',
#        'q': '98582.04449700',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '33.52410000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834351217,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036310,
#        'Q': '70374.14384100',
#        'T': 1650834359999,
#        'V': '23.93240000',
#        'c': '2940.56000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 98,
#        'o': '2940.38000000',
#        'q': '105077.16126000',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '35.73290000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834353270,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036316,
#        'Q': '70374.14384100',
#        'T': 1650834359999,
#        'V': '23.93240000',
#        'c': '2940.44000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.38000000',
#        'n': 104,
#        'o': '2940.38000000',
#        'q': '122884.81213200',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '41.78900000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834355924,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036320,
#        'Q': '70487.34731600',
#        'T': 1650834359999,
#        'V': '23.97090000',
#        'c': '2940.35000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 108,
#        'o': '2940.38000000',
#        'q': '123087.69704100',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '41.85800000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834358472,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036321,
#        'Q': '70487.34731600',
#        'T': 1650834359999,
#        'V': '23.97090000',
#        'c': '2940.34000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 109,
#        'o': '2940.38000000',
#        'q': '123114.16010100',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '41.86700000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834360002,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036329,
#        'Q': '70562.62027600',
#        'T': 1650834359999,
#        'V': '23.99650000',
#        'c': '2940.35000000',
#        'f': 809036213,
#        'h': '2941.18000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 117,
#        'o': '2940.38000000',
#        'q': '123411.72276500',
#        's': 'ETHUSDT',
#        't': 1650834300000,
#        'v': '41.96820000',
#        'x': True},
#  's': 'ETHUSDT'}
# candle closed at 2940.35000000
# closes
# [2940.35]
# received message
# {'E': 1650834362304,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036342,
#        'Q': '396.35918000',
#        'T': 1650834419999,
#        'V': '0.13480000',
#        'c': '2940.35000000',
#        'f': 809036330,
#        'h': '2940.35000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 13,
#        'o': '2940.34000000',
#        'q': '658.63750800',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '0.22400000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834365157,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036344,
#        'Q': '396.35918000',
#        'T': 1650834419999,
#        'V': '0.13480000',
#        'c': '2940.34000000',
#        'f': 809036330,
#        'h': '2940.35000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 15,
#        'o': '2940.34000000',
#        'q': '1715.98377200',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '0.58360000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834367166,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036363,
#        'Q': '21177.37405900',
#        'T': 1650834419999,
#        'V': '7.20150000',
#        'c': '2941.13000000',
#        'f': 809036330,
#        'h': '2941.13000000',
#        'i': '1m',
#        'l': '2940.34000000',
#        'n': 34,
#        'o': '2940.34000000',
#        'q': '22496.99865100',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v':
000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2938.41000000',
#        'n': 198,
#        'o': '2940.34000000',
#        'q': '333449.25498500',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '113.39630000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834406567,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036549,
#        'Q': '34711.03048300',
#        'T': 1650834419999,
#        'V': '11.80590000',
#        'c': '2937.74000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 220,
#        'o': '2940.34000000',
#        'q': '350501.49629900',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '119.20000000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834409878,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036555,
#        'Q': '34760.97206300',
#        'T': 1650834419999,
#        'V': '11.82290000',
#        'c': '2937.73000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 226,
#        'o': '2940.34000000',
#        'q': '352430.40998700',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '119.85660000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834412271,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036563,
#        'Q': '34803.86306700',
#        'T': 1650834419999,
#        'V': '11.83750000',
#        'c': '2937.74000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 234,
#        'o': '2940.34000000',
#        'q': '358044.70593600',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '121.76770000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834415474,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036566,
#        'Q': '35508.03934500',
#        'T': 1650834419999,
#        'V': '12.07720000',
#        'c': '2937.74000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 237,
#        'o': '2940.34000000',
#        'q': '359121.97392400',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '122.13440000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834418488,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036570,
#        'Q': '37094.12517100',
#        'T': 1650834419999,
#        'V': '12.61710000',
#        'c': '2937.74000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 241,
#        'o': '2940.34000000',
#        'q': '360822.33744700',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '122.71320000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834420003,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036587,
#        'Q': '37745.42212900',
#        'T': 1650834419999,
#        'V': '12.83880000',
#        'c': '2937.74000000',
#        'f': 809036330,
#        'h': '2941.54000000',
#        'i': '1m',
#        'l': '2937.73000000',
#        'n': 258,
#        'o': '2940.34000000',
#        'q': '369146.69139200',
#        's': 'ETHUSDT',
#        't': 1650834360000,
#        'v': '125.54680000',
#        'x': True},
#  's': 'ETHUSDT'}
# candle closed at 2937.74000000
# closes
# [2940.35, 2937.74]
# received message
# {'E': 1650834422003,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036654,
#        'Q': '329.60195500',
#        'T': 1650834479999,
#        'V': '0.11220000',
#        'c': '2937.04000000',
#        'f': 809036588,
#        'h': '2937.74000000',
#        'i': '1m',
#        'l': '2937.04000000',
#        'n': 67,
#        'o': '2937.73000000',
#        'q': '70790.35682700',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '24.09870000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834424130,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036690,
#        'Q': '6428.26496100',
#        'T': 1650834479999,
#        'V': '2.18870000',
#        'c': '2936.68000000',
#        'f': 809036588,
#        'h': '2937.74000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 103,
#        'o': '2937.73000000',
#        'q': '87636.99888600',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '29.83490000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834427386,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036717,
#        'Q': '59244.59498500',
#        'T': 1650834479999,
#        'V': '20.17360000',
#        'c': '2937.02000000',
#        'f': 809036588,
#        'h': '2937.74000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 130,
#        'o': '2937.73000000',
#        'q': '140453.32891000',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '47.81980000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834429412,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036731,
#        'Q': '71756.93072900',
#        'T': 1650834479999,
#        'V': '24.43380000',
#        'c': '2937.23000000',
#        'f': 809036588,
#        'h': '2937.74000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 144,
#        'o': '2937.73000000',
#        'q': '172113.67299900',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '58.59950000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834432146,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036732,
#        'Q': '71771.61692900',
#        'T': 1650834479999,
#        'V': '24.43880000',
#        'c': '2937.24000000',
#        'f': 809036588,
#        'h': '2937.74000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 145,
#        'o': '2937.73000000',
#        'q': '172128.35919900',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '58.60450000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834434535,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809

#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036813,
#        'Q': '206870.27815000',
#        'T': 1650834479999,
#        'V': '70.41920000',
#        'c': '2938.31000000',
#        'f': 809036588,
#        'h': '2938.31000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 226,
#        'o': '2937.73000000',
#        'q': '320732.58312000',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '109.18130000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834473707,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036816,
#        'Q': '206885.26353100',
#        'T': 1650834479999,
#        'V': '70.42430000',
#        'c': '2938.30000000',
#        'f': 809036588,
#        'h': '2938.31000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 229,
#        'o': '2937.73000000',
#        'q': '322747.37548100',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '109.86700000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834476711,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036828,
#        'Q': '206885.26353100',
#        'T': 1650834479999,
#        'V': '70.42430000',
#        'c': '2938.00000000',
#        'f': 809036588,
#        'h': '2938.31000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 241,
#        'o': '2937.73000000',
#        'q': '352535.43728600',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '120.00520000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834479721,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036835,
#        'Q': '207170.54333100',
#        'T': 1650834479999,
#        'V': '70.52140000',
#        'c': '2937.99000000',
#        'f': 809036588,
#        'h': '2938.31000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 248,
#        'o': '2937.73000000',
#        'q': '353676.25977400',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '120.39350000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834480011,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036847,
#        'Q': '207479.32713100',
#        'T': 1650834479999,
#        'V': '70.62650000',
#        'c': '2937.99000000',
#        'f': 809036588,
#        'h': '2938.31000000',
#        'i': '1m',
#        'l': '2936.68000000',
#        'n': 260,
#        'o': '2937.73000000',
#        'q': '354260.33323700',
#        's': 'ETHUSDT',
#        't': 1650834420000,
#        'v': '120.59230000',
#        'x': True},
#  's': 'ETHUSDT'}
# candle closed at 2937.99000000
# closes
# [2940.35, 2937.74, 2937.99]
# received message
# {'E': 1650834482734,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036861,
#        'Q': '334.93200000',
#        'T': 1650834539999,
#        'V': '0.11400000',
#        'c': '2937.95000000',
#        'f': 809036848,
#        'h': '2938.00000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 14,
#        'o': '2937.99000000',
#        'q': '26329.32895400',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '8.96180000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834485168,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036867,
#        'Q': '334.93200000',
#        'T': 1650834539999,
#        'V': '0.11400000',
#        'c': '2937.95000000',
#        'f': 809036848,
#        'h': '2938.00000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 20,
#        'o': '2937.99000000',
#        'q': '45687.77529900',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '15.55090000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834488759,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036883,
#        'Q': '24484.75886800',
#        'T': 1650834539999,
#        'V': '8.33390000',
#        'c': '2938.21000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 36,
#        'o': '2937.99000000',
#        'q': '99328.12211600',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '33.80770000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834491093,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036887,
#        'Q': '24484.75886800',
#        'T': 1650834539999,
#        'V': '8.33390000',
#        'c': '2938.21000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 40,
#        'o': '2937.99000000',
#        'q': '99490.01748700',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '33.86280000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834493240,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036897,
#        'Q': '24522.66139000',
#        'T': 1650834539999,
#        'V': '8.34680000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 50,
#        'o': '2937.99000000',
#        'q': '129423.90042600',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '44.05060000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834495350,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036901,
#        'Q': '25682.36103600',
#        'T': 1650834539999,
#        'V': '8.74150000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 54,
#        'o': '2937.99000000',
#        'q': '139052.87509700',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '47.32780000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834498061,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036908,
#        'Q': '28714.56279600',
#        'T': 1650834539999,
#        'V': '9.77350000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 61,
#        'o': '2937.99000000',
#        'q': '142118.86581200',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '48.37130000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834500963,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036909,
#        'Q': '28864.40997600',
#        'T': 1650834539999,
#        'V': '9.82450000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 62,
#        'o': '2937.99000000',
#        'q': '142268.71299200',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '48.42230000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834503143,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036912,
#        'Q': '29417.96308800',
#        'T': 1650834539999,
#        'V': '10.01290000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 65,
#        'o': '2937.99000000',
#        'q': '142839.89512400',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '48.61670000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834505270,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036916,
#        'Q': '30679.02994400',
#        'T': 1650834539999,
#        'V': '10.44210000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 69,
#        'o': '2937.99000000',
#        'q': '144811.41148600',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '49.28770000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834509063,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036917,
#        'Q': '30679.02994400',
#        'T': 1650834539999,
#        'V': '10.44210000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 70,
#        'o': '2937.99000000',
#        'q': '145108.46047300',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '49.38880000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834511229,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036920,
#        'Q': '31308.68191800',
#        'T': 1650834539999,
#        'V': '10.65640000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 73,
#        'o': '2937.99000000',
#        'q': '145755.74146700',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '49.60910000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834514493,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036923,
#        'Q': '31308.68191800',
#        'T': 1650834539999,
#        'V': '10.65640000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 76,
#        'o': '2937.99000000',
#        'q': '148042.22536100',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '50.38730000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834516862,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036925,
#        'Q': '31308.68191800',
#        'T': 1650834539999,
#        'V': '10.65640000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 78,
#        'o': '2937.99000000',
#        'q': '150366.61164800',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '51.17840000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834519124,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036927,
#        'Q': '31308.68191800',
#        'T': 1650834539999,
#        'V': '10.65640000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 80,
#        'o': '2937.99000000',
#        'q': '150429.19466900',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '51.19970000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834522942,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036928,
#        'Q': '31780.55362600',
#        'T': 1650834539999,
#        'V': '10.81700000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 81,
#        'o': '2937.99000000',
#        'q': '150901.06637700',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '51.36030000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834525061,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036931,
#        'Q': '33341.60866000',
#        'T': 1650834539999,
#        'V': '11.34830000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 84,
#        'o': '2937.99000000',
#        'q': '152485.62677100',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '51.89960000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834527919,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036933,
#        'Q': '33746.78368200',
#        'T': 1650834539999,
#        'V': '11.48620000',
#        'c': '2938.18000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 86,
#        'o': '2937.99000000',
#        'q': '152890.80179300',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '52.03750000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834530926,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036934,
#        'Q': '33746.78368200',
#        'T': 1650834539999,
#        'V': '11.48620000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 87,
#        'o': '2937.99000000',
#        'q': '152908.43081300',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '52.04350000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834533939,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036940,
#        'Q': '34454.00360800',
#        'T': 1650834539999,
#        'V': '11.72690000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 93,
#        'o': '2937.99000000',
#        'q': '158267.36148300',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '53.86740000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834537381,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036941,
#        'Q': '34454.00360800',
#        'T': 1650834539999,
#        'V': '11.72690000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 94,
#        'o': '2937.99000000',
#        'q': '158293.80501300',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '53.87640000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834539818,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036943,
#        'Q': '34500.72067000',
#        'T': 1650834539999,
#        'V': '11.74280000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 96,
#        'o': '2937.99000000',
#        'q': '158957.53777500',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '54.10230000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834540006,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036959,
#        'Q': '34844.48773000',
#        'T': 1650834539999,
#        'V': '11.85980000',
#        'c': '2938.17000000',
#        'f': 809036848,
#        'h': '2938.21000000',
#        'i': '1m',
#        'l': '2937.95000000',
#        'n': 112,
#        'o': '2937.99000000',
#        'q': '159794.91739500',
#        's': 'ETHUSDT',
#        't': 1650834480000,
#        'v': '54.38730000',
#        'x': True},
#  's': 'ETHUSDT'}
# candle closed at 2938.17000000
# closes
# [2940.35, 2937.74, 2937.99, 2938.17]
# received message
# {'E': 1650834542116,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809036965,
#        'Q': '228.00276800',
#        'T': 1650834599999,
#        'V': '0.07760000',
#        'c': '2938.17000000',
#        'f': 809036960,
#        'h': '2938.18000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 6,
#        'o': '2938.18000000',
#        'q': '315.26641700',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '0.10730000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834544207,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037010,
#        'Q': '203027.44360900',
#        'T': 1650834599999,
#        'V': '69.09770000',
#        'c': '2938.91000000',
#        'f': 809036960,
#        'h': '2938.92000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 51,
#        'o': '2938.18000000',
#        'q': '203229.32435800',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '69.16640000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834546969,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037022,
#        'Q': '239956.82626900',
#        'T': 1650834599999,
#        'V': '81.66330000',
#        'c': '2939.13000000',
#        'f': 809036960,
#        'h': '2939.13000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 63,
#        'o': '2938.18000000',
#        'q': '240158.70701800',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '81.73200000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834549369,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037025,
#        'Q': '240841.21618600',
#        'T': 1650834599999,
#        'V': '81.96420000',
#        'c': '2939.39000000',
#        'f': 809036960,
#        'h': '2939.39000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 66,
#        'o': '2938.18000000',
#        'q': '241043.09693500',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '82.03290000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834551903,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037030,
#        'Q': '241519.94814000',
#        'T': 1650834599999,
#        'V': '82.19510000',
#        'c': '2939.88000000',
#        'f': 809036960,
#        'h': '2939.88000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 71,
#        'o': '2938.18000000',
#        'q': '241721.82888900',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '82.26380000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834554758,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037039,
#        'Q': '242080.87724400',
#        'T': 1650834599999,
#        'V': '82.38590000',
#        'c': '2939.87000000',
#        'f': 809036960,
#        'h': '2939.88000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 80,
#        'o': '2938.18000000',
#        'q': '242371.83605400',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '82.48490000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834557386,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037041,
#        'Q': '242091.46081200',
#        'T': 1650834599999,
#        'V': '82.38950000',
#        'c': '2939.88000000',
#        'f': 809036960,
#        'h': '2939.88000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 82,
#        'o': '2938.18000000',
#        'q': '242405.93858200',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '82.49650000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834559787,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037045,
#        'Q': '242580.65817200',
#        'T': 1650834599999,
#        'V': '82.55590000',
#        'c': '2939.89000000',
#        'f': 809036960,
#        'h': '2939.90000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 86,
#        'o': '2938.18000000',
#        'q': '246268.95370600',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '83.81050000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834561836,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037062,
#        'Q': '285504.57179900',
#        'T': 1650834599999,
#        'V': '97.15420000',
#        'c': '2940.59000000',
#        'f': 809036960,
#        'h': '2940.59000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 103,
#        'o': '2938.18000000',
#        'q': '289254.91378200',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '98.42990000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834564034,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037065,
#        'Q': '285504.57179900',
#        'T': 1650834599999,
#        'V': '97.15420000',
#        'c': '2940.79000000',
#        'f': 809036960,
#        'h': '2940.79000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 106,
#        'o': '2938.18000000',
#        'q': '291099.35445000',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '99.05710000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1650834567179,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 809037066,
#        'Q': '285504.57179900',
#        'T': 1650834599999,
#        'V': '97.15420000',
#        'c': '2940.79000000',
#        'f': 809036960,
#        'h': '2940.79000000',
#        'i': '1m',
#        'l': '2938.17000000',
#        'n': 107,
#        'o': '2938.18000000',
#        'q': '291741.03482800',
#        's': 'ETHUSDT',
#        't': 1650834540000,
#        'v': '99.27530000',
#        'x': False},
#  's': 'ETHUSDT'}
# False

# %%
startTimes = 1646110800000
candles = []

while(len(candles) >= 50000):
    startTimes.append9
candles = client.get_klines(symbol='BNBBTC', 
                            interval=Client.KLINE_INTERVAL_1MINUTE, 
                            startTime = (1646110800000), 
                            endTime = (1648785600000))


print(len(candles))
# Out:
# 500
